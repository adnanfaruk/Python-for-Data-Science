# %% [markdown]
# # The Pima Indians Diabetes Dataset
#
# #### Problem Statement: The Pima Indians Diabetes Dataset involves predicting the onset of diabetes within 5 years in Pima Indians given medical details. It is a binary (2-class) classification problem. The number of observations for each class is not balanced. There are 768 observations with 8 input variables and 1 output variable. Missing values are believed to be encoded with zero values. The variable names are as follows:
#
# 1. Number of times pregnant.
# 2. Plasma glucose concentration 2 hours in an oral glucose tolerance test.
# 3. Diastolic blood pressure (mm Hg).
# 4. Triceps skinfold thickness (mm).
# 5. 2-Hour serum insulin (mu U/ml).
# 6. Body mass index (weight in kg/(height in m)^2).
# 7. Diabetes pedigree function.
# 8. Age (years).
# 9. Is Diabetic (0 or 1).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix
import xgboost as xgb
from xgboost import XGBRFClassifier   
from sklearn import datasets

# %%
data=pd.read_csv('pima-indians-diabetes.csv')
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                           148
# 1                           1                            85
# 2                           8                           183
# 3                           1                            89
# 4                           0                           137
# ..                        ...                           ...
# 763                        10                           101
# 764                         2                           122
# 765                         5                           121
# 766                         1                           126
# 767                         1                            93
#
#      Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                                  72                               35
# 1                                  66                               29
# 2                                  64                                0
# 3                                  66                               23
# 4                                  40                               35
# ..                                ...                              ...
# 763                                76                               48
# 764                                70                               27
# 765                                72                               23
# 766                                60                                0
# 767                                70                               31
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                94
# 4                               168
# ..                              ...
# 763                             180
# 764                               0
# 765                             112
# 766                               0
# 767                               0
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                              33.6
# 1                                              26.6
# 2                                              23.3
# 3                                              28.1
# 4                                              43.1
# ..                                              ...
# 763                                            32.9
# 764                                            36.8
# 765                                            26.2
# 766                                            30.1
# 767                                            30.4
#
#      Diabetes pedigree function  Age  Is Diabetic
# 0                         0.627   50            1
# 1                         0.351   31            0
# 2                         0.672   32            1
# 3                         0.167   21            0
# 4                         2.288   33            1
# ..                          ...  ...          ...
# 763                       0.171   63            0
# 764                       0.340   27            0
# 765                       0.245   30            0
# 766                       0.349   47            1
# 767                       0.315   23            0
#
# [768 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Number of times pregnant                        768 non-null    int64
#  1   Plasma glucose concentration                    768 non-null    int64
#  2   Diastolic blood pressure (mm Hg)                768 non-null    int64
#  3   Triceps skinfold thickness (mm)                 768 non-null    int64
#  4   2-Hour serum insulin (mu U/ml)                  768 non-null    int64
#  5   Body mass index (weight in kg/(height in m)^2)  768 non-null    float64
#  6   Diabetes pedigree function                      768 non-null    float64
#  7   Age                                             768 non-null    int64
#  8   Is Diabetic                                     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    768.000000
# mean                   3.845052                    120.894531
# std                    3.369578                     31.972618
# min                    0.000000                      0.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    140.250000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# count                        768.000000                       768.000000
# mean                          69.105469                        20.536458
# std                           19.355807                        15.952218
# min                            0.000000                         0.000000
# 25%                           62.000000                         0.000000
# 50%                           72.000000                        23.000000
# 75%                           80.000000                        32.000000
# max                          122.000000                        99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function         Age  Is Diabetic
# count                  768.000000  768.000000   768.000000
# mean                     0.471876   33.240885     0.348958
# std                      0.331329   11.760232     0.476951
# min                      0.078000   21.000000     0.000000
# 25%                      0.243750   24.000000     0.000000
# 50%                      0.372500   29.000000     0.000000
# 75%                      0.626250   41.000000     1.000000
# max                      2.420000   81.000000     1.000000

# %%
#wie in der Datenbeschreibung erwähnt, wurden die fehlenden Werte durch Nullen ersetzt. Wir ersetzen also die Nullen durch nan

column=['Plasma glucose concentration',
       'Diastolic blood pressure (mm Hg)', 'Triceps skinfold thickness (mm)',
       '2-Hour serum insulin (mu U/ml)',
       'Body mass index (weight in kg/(height in m)^2)',
       'Diabetes pedigree function', 'Age']

# %%
for i in column:
    data[i]=data[i].replace(0,np.nan)

# %%
data.isna().sum()
# Out:
# Number of times pregnant                            0
# Plasma glucose concentration                        5
# Diastolic blood pressure (mm Hg)                   35
# Triceps skinfold thickness (mm)                   227
# 2-Hour serum insulin (mu U/ml)                    374
# Body mass index (weight in kg/(height in m)^2)     11
# Diabetes pedigree function                          0
# Age                                                 0
# Is Diabetic                                         0
# dtype: int64

# %%
data['Plasma glucose concentration'].mode()[0]
# Out:
# 99.0

# %%
data['Plasma glucose concentration']=data['Plasma glucose concentration'].fillna(data['Plasma glucose concentration'].mode()[0])
data['Diastolic blood pressure (mm Hg)']=data['Diastolic blood pressure (mm Hg)'].fillna(data['Diastolic blood pressure (mm Hg)'].mode()[0])
data['Triceps skinfold thickness (mm)']=data['Triceps skinfold thickness (mm)'].fillna(data['Triceps skinfold thickness (mm)'].mean())
data['2-Hour serum insulin (mu U/ml)']=data['2-Hour serum insulin (mu U/ml)'].fillna(data['2-Hour serum insulin (mu U/ml)'].mean())
data['Body mass index (weight in kg/(height in m)^2)']=data['Body mass index (weight in kg/(height in m)^2)'].fillna(data['Body mass index (weight in kg/(height in m)^2)'].mean())

# %%
data.isna().sum()
# Out:
# Number of times pregnant                          0
# Plasma glucose concentration                      0
# Diastolic blood pressure (mm Hg)                  0
# Triceps skinfold thickness (mm)                   0
# 2-Hour serum insulin (mu U/ml)                    0
# Body mass index (weight in kg/(height in m)^2)    0
# Diabetes pedigree function                        0
# Age                                               0
# Is Diabetic                                       0
# dtype: int64

# %%
data
# Out:
#      Number of times pregnant  Plasma glucose concentration  \
# 0                           6                         148.0
# 1                           1                          85.0
# 2                           8                         183.0
# 3                           1                          89.0
# 4                           0                         137.0
# ..                        ...                           ...
# 763                        10                         101.0
# 764                         2                         122.0
# 765                         5                         121.0
# 766                         1                         126.0
# 767                         1                          93.0
#
#      Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                                72.0                         35.00000
# 1                                66.0                         29.00000
# 2                                64.0                         29.15342
# 3                                66.0                         23.00000
# 4                                40.0                         35.00000
# ..                                ...                              ...
# 763                              76.0                         48.00000
# 764                              70.0                         27.00000
# 765                              72.0                         23.00000
# 766                              60.0                         29.15342
# 767                              70.0                         31.00000
#
#      2-Hour serum insulin (mu U/ml)  \
# 0                        155.548223
# 1                        155.548223
# 2                        155.548223
# 3                         94.000000
# 4                        168.000000
# ..                              ...
# 763                      180.000000
# 764                      155.548223
# 765                      112.000000
# 766                      155.548223
# 767                      155.548223
#
#      Body mass index (weight in kg/(height in m)^2)  \
# 0                                              33.6
# 1                                              26.6
# 2                                              23.3
# 3                                              28.1
# 4                                              43.1
# ..                                              ...
# 763                                            32.9
# 764                                            36.8
# 765                                            26.2
# 766                                            30.1
# 767                                            30.4
#
#      Diabetes pedigree function  Age  Is Diabetic
# 0                         0.627   50            1
# 1                         0.351   31            0
# 2                         0.672   32            1
# 3                         0.167   21            0
# 4                         2.288   33            1
# ..                          ...  ...          ...
# 763                       0.171   63            0
# 764                       0.340   27            0
# 765                       0.245   30            0
# 766                       0.349   47            1
# 767                       0.315   23            0
#
# [768 rows x 9 columns]

# %%
#Die Daten unterscheiden sich stark in ihrer Größenordnung, so dass sie skaliert werden müssen.
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

# %%
x=data.drop('Is Diabetic',axis=1)
y=data['Is Diabetic']

# %%
scaled_data=scale.fit_transform(x)
scaled_data
# Out:
# array([[ 0.63994726,  0.86840303, -0.02442979, ...,  0.16629174,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.19914997, -0.52034382, ..., -0.85253118,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  2.01704359, -0.68564849, ..., -1.33283341,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 , -0.01769112, -0.02442979, ..., -0.91074963,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.14640039, -1.01625784, ..., -0.34311972,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.93660356, -0.18973447, ..., -0.29945588,
#         -0.47378505, -0.87137393]])

# %%
pd.DataFrame(scaled_data)
# Out:
#             0         1         2             3             4         5  \
# 0    0.639947  0.868403 -0.024430  6.655021e-01 -3.345079e-16  0.166292
# 1   -0.844885 -1.199150 -0.520344 -1.746338e-02 -3.345079e-16 -0.852531
# 2    1.233880  2.017044 -0.685648  8.087936e-16 -3.345079e-16 -1.332833
# 3   -0.844885 -1.067877 -0.520344 -7.004289e-01 -7.243887e-01 -0.634212
# 4   -1.141852  0.507402 -2.669305  6.655021e-01  1.465506e-01  1.548980
# ..        ...       ...       ...           ...           ...       ...
# 763  1.827813 -0.674057  0.306180  2.145261e+00  2.877840e-01  0.064409
# 764 -0.547919  0.015127 -0.189734 -2.451185e-01 -3.345079e-16  0.632039
# 765  0.342981 -0.017691 -0.024430 -7.004289e-01 -5.125386e-01 -0.910750
# 766 -0.844885  0.146400 -1.016258  8.087936e-16 -3.345079e-16 -0.343120
# 767 -0.844885 -0.936604 -0.189734  2.101918e-01 -3.345079e-16 -0.299456
#
#             6         7
# 0    0.468492  1.425995
# 1   -0.365061 -0.190672
# 2    0.604397 -0.105584
# 3   -0.920763 -1.041549
# 4    5.484909 -0.020496
# ..        ...       ...
# 763 -0.908682  2.532136
# 764 -0.398282 -0.531023
# 765 -0.685193 -0.275760
# 766 -0.371101  1.170732
# 767 -0.473785 -0.871374
#
# [768 rows x 8 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(scaled_data,y,test_size=.30,random_state=355)

# %%
model=XGBRFClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# XGBRFClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bytree=1, gamma=0, gpu_id=-1, importance_type='gain',
#                 interaction_constraints='', max_delta_step=0, max_depth=6,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimators=100, n_jobs=0, num_parallel_tree=100,
#                 objective='binary:logistic', random_state=0, reg_alpha=0,
#                 scale_pos_weight=1, tree_method='exact', validate_parameters=1,
#                 verbosity=None)

# %%
#train accurarcy
y_pred=model.predict(x_train)
pre=[round(value) for value in y_pred]
accuracy=accuracy_score(y_train,pre)
accuracy
# Out:
# 0.9199255121042831

# %%
#test accuracy
y_pred=model.predict(x_test)
accurac=accuracy_score(y_test,y_pred)
accurac
# Out:
# 0.7359307359307359

# %%
#hyperparameter 
from sklearn.model_selection import GridSearchCV

# %%
peram_grid={
    
    'learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimatores':[10,50,100,200]
    
    
}

# %%
grid=GridSearchCV(XGBRFClassifier(),peram_grid,verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV] learning_rate=1, max_depth=3, n_estimatores=10 ..................
# [15:09:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=1, max_depth=3, n_estimatores=10, score=0.787, total=   0.1s
# [CV] learning_rate=1, max_depth=3, n_estimatores=10 ..................
# [15:09:03] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=1, max_depth=3, n_estimatores
09:07] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
# ...
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=100, score=0.841, total=   0.1s
# [CV] learning_rate=0.001, max_depth=10, n_estimatores=200 ............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=200, score=0.796, total=   0.1s
# [CV] learning_rate=0.001, max_depth=10, n_estimatores=200 ............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=200, score=0.769, total=   0.0s
# [CV] learning_rate=0.001, max_depth=10, n_estimatores=200 ............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=200, score=0.748, total=   0.0s
# [CV] learning_rate=0.001, max_depth=10, n_estimatores=200 ............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=200, score=0.729, total=   0.1s
# [CV] learning_rate=0.001, max_depth=10, n_estimatores=200 ............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=10, n_estimatores=200, score=0.841, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=10 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=10, score=0.796, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=10 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=10, score=0.769, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=10 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=10, score=0.748, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=10 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=10, score=0.729, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=10 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=10, score=0.841, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=50 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=50, score=0.796, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=50 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=50, score=0.769, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=50 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=50, score=0.748, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=50 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=50, score=0.729, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=50 .............
# [15:09:21] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=50, score=0.841, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=100 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=100, score=0.796, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=100 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=100, score=0.769, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=100 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=100, score=0.748, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=100 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=100, score=0.729, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=100 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=100, score=0.841, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=200 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=200, score=0.796, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=200 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=200, score=0.769, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=200 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=200, score=0.748, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=200 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=200, score=0.729, total=   0.1s
# [CV] learning_rate=0.001, max_depth=20, n_estimatores=200 ............
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [CV]  learning_rate=0.001, max_depth=20, n_estimatores=200, score=0.841, total=   0.1s
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [Parallel(n_jobs=1)]: Done 400 out of 400 | elapsed:   19.4s finished
# GridSearchCV(estimator=XGBRFClassifier(base_score=None, booster=None,
#                                        colsample_bylevel=None,
#                                        colsample_bytree=None, gamma=None,
#                                        gpu_id=None, importance_type='gain',
#                                        interaction_constraints=None,
#                                        max_delta_step=None, max_depth=None,
#                                        min_child_weight=None, missing=nan,
#                                        monotone_constraints=None,
#                                        n_estimators=100, n_jobs=None,
#                                        num_parallel_tree=None,
#                                        objective='binary:logistic',
#                                        random_state=None, reg_alpha=None,
#                                        scale_pos_weight=None, tree_method=None,
#                                        validate_parameters=None,
#                                        verbosity=None),
#              param_grid={'learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 10, 20],
#                          'n_estimatores': [10, 50, 100, 200]},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'learning_rate': 1, 'max_depth': 10, 'n_estimatores': 10}

# %%
new_model=XGBRFClassifier(learning_rate= 1, max_depth= 10, n_estimatores= 10)

# %%
new_model.fit(x_train,y_train)
# Out:
# [15:09:22] WARNING: /Users/runner/miniforge3/conda-bld/xgboost_1593723618214/work/src/learner.cc:480:
# Parameters: { n_estimatores } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRFClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#                 colsample_bytree=1, gamma=0, gpu_id=-1, importance_type='gain',
#                 interaction_constraints='', max_delta_step=0, max_depth=10,
#                 min_child_weight=1, missing=nan, monotone_constraints='()',
#                 n_estimatores=10, n_estimators=100, n_jobs=0,
#                 num_parallel_tree=100, objective='binary:logistic',
#                 random_state=0, reg_alpha=0, scale_pos_weight=1,
#                 tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_new_pred=new_model.predict(x_test)
new_acc=accuracy_score(y_test,y_new_pred)
new_acc
# Out:
# 0.7316017316017316

# %%
import pickle
with open("XGBoost_model.pickel",'wb') as f:
    pickle.dump(new_model,f)

# %%
with open("XGBoost_model.pickel",'rb') as f:
    mp=pickle.load(f)

# %%
with open('scaler_model.pickle','wb') as f:
    pickle.dump(scale,f)

# %%
with open('scaler_model.pickle','rb') as f:
    sc=pickle.load(f)

# %%
#nun betrachen wir ob eine Vorhersage treffen können
d=sc.transform([[1,85.0,66.0,29.00000,155.548223,26.6,0.351,31]])
d
# Out:
# array([[-8.44885053e-01, -1.19914997e+00, -5.20343817e-01,
#         -1.74633816e-02, -4.12229492e-09, -8.52531177e-01,
#         -3.65060778e-01, -1.90671905e-01]])

# %%
final=mp.predict(d)
print('his data belongs to class',final[0])
# Out:
# this data belongs to class 0
